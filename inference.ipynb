# %%
import numpy as np
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
model = load_model('model_seq.keras')

# %%
def prediction(file):
  img = tf.keras.utils.load_img(file, target_size=(224, 224))
  x = tf.keras.utils.img_to_array(img)/255

  plt.imshow(img)

  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  idx = np.argmax(classes)
  label = ['Brain Tumor', 'Healthy']
  print('Prediction is a {}'.format(label[idx]))

# %%
prediction('/content/Screenshot 2024-01-22 155652.jpg')
# Out:
# 1/1 [==============================] - 1s 539ms/step
# Prediction is a Brain Tumor

# %%
prediction('/content/image_2024-01-22_190847496.png')
# Out:
# 1/1 [==============================] - 0s 54ms/step
# Prediction is a Healthy
